# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/artists.csv')
df
# Out:
#                            id  followers genres  \
# 0      0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1      0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2      0DmRESX2JknGPQyO15yxg7        0.0     []
# 3      0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4      0Dn11fWM7vHQ3rinvWEl4E        2.0     []
# ...                       ...        ...    ...
# 70738  00xYr0oHsJTZgOBjDrBUJk        1.0     []
# 70739  00xxwzxCFcqH3FmeaVVeWo        0.0     []
# 70740  00y1efBnf23dQbbXmwEQtG        2.0     []
# 70741  6S6DSFrzMkUrAc1F8OvGTu       56.0     []
# 70742                7dqo3qQz        NaN    NaN
#
#                                                  name  popularity
# 0      Armid & Amir Zare Pashai feat. Sara Rouzbehani         0.0
# 1                                         ปูนา ภาวิณี         0.0
# 2                                               Sadaa         0.0
# 3                                           Tra'gruda         0.0
# 4                              Ioannis Panoutsopoulos         0.0
# ...                                               ...         ...
# 70738                                     Souljakrank         0.0
# 70739                                       Rome Jefe         0.0
# 70740                                     Ninte Music         0.0
# 70741                                   Art.Mos.Phere        35.0
# 70742                                             NaN         NaN
#
# [70743 rows x 5 columns]

# %%
df.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani         0.0
# 1                                     ปูนา ภาวิณี         0.0
# 2                                           Sadaa         0.0
# 3                                       Tra'gruda         0.0
# 4                          Ioannis Panoutsopoulos         0.0

# %%
df.tail()
# Out:
#                            id  followers genres           name  popularity
# 70738  00xYr0oHsJTZgOBjDrBUJk        1.0     []    Souljakrank         0.0
# 70739  00xxwzxCFcqH3FmeaVVeWo        0.0     []      Rome Jefe         0.0
# 70740  00y1efBnf23dQbbXmwEQtG        2.0     []    Ninte Music         0.0
# 70741  6S6DSFrzMkUrAc1F8OvGTu       56.0     []  Art.Mos.Phere        35.0
# 70742                7dqo3qQz        NaN    NaN            NaN         NaN

# %%
df.columns
# Out:
# Index(['id', 'followers', 'genres', 'name', 'popularity'], dtype='object')

# %%
len(df.columns)
# Out:
# 5

# %%
len(df)
# Out:
# 70743

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70743 entries, 0 to 70742
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          70743 non-null  object
#  1   followers   70742 non-null  float64
#  2   genres      70742 non-null  object
#  3   name        70742 non-null  object
#  4   popularity  70742 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.7+ MB

# %%
df.describe()
# Out:
#           followers    popularity
# count  7.074200e+04  70742.000000
# mean   1.313671e+04     17.715261
# std    6.963480e+04     18.768157
# min    0.000000e+00      0.000000
# 25%    2.000000e+00      0.000000
# 50%    5.400000e+01     12.000000
# 75%    3.698000e+03     34.000000
# max    4.562300e+06     89.000000

# %%
print(df[['followers', 'popularity']].describe())
# Out:
#           followers    popularity
# count  7.074200e+04  70742.000000
# mean   1.313671e+04     17.715261
# std    6.963480e+04     18.768157
# min    0.000000e+00      0.000000
# 25%    2.000000e+00      0.000000
# 50%    5.400000e+01     12.000000
# 75%    3.698000e+03     34.000000
# max    4.562300e+06     89.000000

# %%
df.shape
# Out:
# (70743, 5)

# %%
df.isnull().sum()
# Out:
# id            0
# followers     1
# genres        1
# name          1
# popularity    1
# dtype: int64

# %%
plt.figure(figsize=(10, 4))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap")
plt.show()

# %%
df['followers'].fillna(0, inplace=True)
# Out:
# /tmp/ipython-input-14-3388126337.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['followers'].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# id            0
# followers     0
# genres        1
# name          1
# popularity    1
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'followers', 'genres', 'name', 'popularity'], dtype='object')

# %%
df.id.nunique()
# Out:
# 70743

# %%
df.id.unique()
# Out:
# array(['0DheY5irMjBUeLybbCUEZ2', '0DlhY15l3wsrnlfGio2bjU',
#        '0DmRESX2JknGPQyO15yxg7', ..., '00y1efBnf23dQbbXmwEQtG',
#        '6S6DSFrzMkUrAc1F8OvGTu', '7dqo3qQz'], dtype=object)

# %%
df.followers.nunique()
# Out:
# 18093

# %%
df.followers.unique()
# Out:
# array([0.00000e+00, 5.00000e+00, 2.00000e+00, ..., 2.25600e+03,
#        1.10010e+05, 2.54032e+05])

# %%
df.genres.unique()
# Out:
# array(['[]', "['carnaval cadiz']", "['classical harp', 'harp']", ...,
#        "['danspunk', 'eurovision', 'swedish pop']",
#        "['italian hip hop', 'trap metal italiana']", nan], dtype=object)

# %%
import pandas as pd
import ast
def safe_convert_to_list(val):
    try:
        return ast.literal_eval(val)
    except (ValueError, SyntaxError):
        return []
df['genres'] = df['genres'].astype(str).apply(safe_convert_to_list)

print(df['genres'])
# Out:
# 0        []
# 1        []
# 2        []
# 3        []
# 4        []
#          ..
# 70738    []
# 70739    []
# 70740    []
# 70741    []
# 70742    []
# Name: genres, Length: 70743, dtype: object

# %%
unique_genres_tuples = df['genres'].apply(tuple).unique()
unique_genres_lists = [list(t) for t in unique_genres_tuples]
print(unique_genres_lists)
# Out:
# [[], ['carnaval cadiz'], ['classical harp', 'harp'], ['classical contralto'], ['british choir'], ["children's story"], ['classic persian pop', 'persian traditional'], ['desi pop', 'punjabi hip hop', 'punjabi pop'], ['afro dancehall', 'afropop', 'azontobeats', 'nigerian hip hop', 'nigerian pop'], ['filmi', 'indian folk', 'indian rock', 'kannada pop'], ['indian fusion'], ['desi pop', 'hindi indie', 'indian indie', 'indian rock', 'new delhi indie', 'sufi'], ['russian electronic'], ['swedish electropop'], ['indian folk'], ['khaliji', 'sheilat'], ['desi pop', 'modern bollywood'], ['afro dancehall', 'afropop', 'alte', 'nigerian pop'], ['environmental', 'sleep'], ['desi hip hop', 'tamil pop'], ['opm', 'pinoy hip hop', 'pinoy r&b', 'pinoy trap', 'tagalog rap'], ['kuduro'], ['australian hip hop', 'australian trap'], ['afropop', 'azontobeats', 'nigerian hip hop', 'nigerian pop'], ['hindi indie', 'indian indie', 'indian singer-songwriter'], ['pinoy hip hop', 'tagalog rap'], ['uk drill'], ['indie hidalguense'], ['comedy', 'comic', 'haitian gospel', 'new comedy'], ['vintage tango'], ['folklore argentino'], ['villancicos'], ['house argentino'], ['rock nacional'], ['blues latinoamericano', 'rock nacional'], ['tango', 'vintage tango'], ['argentine rock', 'rock nacional'], ['tango'], ['italian progressive rock', 'rock nacional'], ['argentine metal', 'latin metal', 'rock nacional'], ['musica andina'], ['musica para ninos'], ['folclore santiagueno'], ['classic venezuelan pop'], ['post-punk argentina'], ['orquesta tipica', 'tango', 'vintage tango'], ['neo-progressive', 'progressive rock'], ['puerto rican rock'], ['folclore tucumano', 'folklore argentino', 'guitarra argentina', 'latin classical'], ['folclore tucumano'], ['cumbia santafesina'], ['chamame', 'folklore argentino'], ['chamame', 'folclore santiagueno', 'folklore argentino'], ['charango', 'folclore jujeno', 'folklore argentino', 'world chill'], ['argentine metal'], ['argentine indie', 'argentine rock', 'indie platense', 'rock nacional'], ['chamame'], ['folclore salteno', 'folklore argentino'], ['argentine rock', 'rock en espanol', 'rock nacional'], ['argentine indie', 'post-punk argentina'], ['argentine indie', 'argentine rock', 'post-punk argentina', 'rock nacional'], ['argentine indie', 'argentine rock', 'rock en espanol', 'rock nacional'], ['cumbia villera'], ['rap underground argentino'], ['dub', 'reggae', 'reggae cover', 'roots reggae'], ['cumbia santafesina', 'cumbia villera'], ['cuarteto'], ['argentine punk'], ['argentine rock'], ['folclore santiagueno', 'folklore nuevo argentino'], ['argentine punk', 'argentine rock'], ['chamame', 'cumbia villera'], ['argentine heavy metal', 'argentine metal', 'latin metal', 'latincore'], ['argentine rock', 'rock en espanol'], ['argentine heavy metal', 'argentine metal', 'latin metal', 'spanish metal'], ['trova'], ['comedia'], ['cuarteto', 'musica blumenauense'], ['folclore salteno'], ['argentine hardcore', 'argentine punk', 'latincore'], ['chilean indie', 'chilean rock', 'latin rock', 'nueva cancion', 'nueva trova chilena', 'trova'], ['folclore santiagueno', 'folklore argentino'], ['cumbia pop', 'cumbia uruguaya', 'plena uruguaya'], ['folclore jujeno', 'folklore argentino', 'folklore nuevo argentino'], ['argentine indie', 'latin afrobeat'], ['coverchill'], ['argentine alternative rock', 'latincore'], ['israeli techno'], ['argentine jazz'], ['chicha', 'chilean rock', 'cumbia chilena', 'latin alternative', 'latin rock', 'nueva cancion'], ['alternative hip hop', 'trap latino'], ['folclore santiagueno', 'folklore argentino', 'nueva cancion'], ['argentine metal', 'argentine rock', 'latin metal', 'latincore', 'rock en espanol'], ['nuevo tango', 'tango'], ['argentine indie', 'argentine rock', 'latin rock'], ['argentine punk', 'latincore'], ['cumbia pop'], ['argentine telepop'], ['argentine indie'], ['indie cordoba'], ['latincore'], ['argentine heavy metal', 'argentine metal', 'argentine rock', 'latin metal'], ['bristol electronic', 'classic progressive ...

# %% [markdown]
# Visualization

# %%
#What is the distribution of followers among artists?
plt.figure(figsize=(10, 5))
sns.histplot(df['followers'], bins=100, kde=True)
plt.xlim(0, df['followers'].quantile(0.95))  # Limit x-axis to avoid outlier skew
plt.title("Distribution of Followers Among Artists")
plt.xlabel("Number of Followers")
plt.ylabel("Count of Artists")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
# Artists with zero followers
zero_followers = df[df['followers'] == 0]
# Artists with zero popularity
zero_popularity = df[df['popularity'] == 0]
# Artists with both zero followers and zero popularity
zero_both = df[(df['followers'] == 0) & (df['popularity'] == 0)]
# Print counts
print("Number of artists with zero followers:", len(zero_followers))
print("Number of artists with zero popularity:", len(zero_popularity))
print("Number of artists with both zero followers and zero popularity:", len(zero_both))
# Out:
# Number of artists with zero followers: 13219
# Number of artists with zero popularity: 26631
# Number of artists with both zero followers and zero popularity: 11998

# %%
#Correlation Between Followers and Popularity
correlation = df[['followers', 'popularity']].corr()
print("Correlation Matrix:\n", correlation)
# Out:
# Correlation Matrix:
#              followers  popularity
# followers    1.000000    0.324537
# popularity   0.324537    1.000000

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.title("Correlation Between Followers and Popularity")
plt.show()

# %%
#Do artists with more followers tend to be more popular?
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='followers', y='popularity', alpha=0.3)
plt.xscale('log')  # Log scale improves visibility
plt.title("Followers vs Popularity")
plt.xlabel("Followers (log scale)")
plt.ylabel("Popularity")
plt.grid(True)
plt.show()

# %%
#Are there outliers in the followers or popularity data?
plt.figure(figsize=(10, 5))
sns.boxplot(data=df[['followers', 'popularity']])
plt.title("Boxplot of Followers and Popularity")
# Out:
# Text(0.5, 1.0, 'Boxplot of Followers and Popularity')

# %%
#What are the top 10 most common genres?
from collections import Counter;
# Count all genres
genre_counter = Counter()
for genre_list in df['genres']:
    genre_counter.update(genre_list)

# Get top 10 most common genres
top_genres = pd.DataFrame(genre_counter.most_common(10), columns=['genre', 'count'])

# Display top genres
print("Top 10 Most Common Genres:\n", top_genres)

# Plot bar chart
plt.figure(figsize=(10, 6))
sns.barplot(data=top_genres, y='genre', x='count', palette='magma')
plt.title("Top 10 Most Common Genres")
plt.xlabel("Number of Artists")
plt.ylabel("Genre")
plt.tight_layout()
plt.show()
# Out:
# Top 10 Most Common Genres:
#                     genre  count
# 0    classic swedish pop    164
# 1            finnish pop    155
# 2             suomi rock    155
# 3                iskelma    152
# 4  classic norwegian pop    148
# 5             danish pop    147
# 6        classic iskelma    147
# 7            swedish pop    142
# 8             rock kapak    140
# 9  classic icelandic pop    139
# /tmp/ipython-input-37-25781196.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_genres, y='genre', x='count', palette='magma')

# %%
#Are there artists associated with multiple genres?
multiple_genres = df[df['genres'].apply(lambda x: len(x) > 1)]
print("Number of artists with multiple genres:", len(multiple_genres))
# Out:
# Number of artists with multiple genres: 11976

# %%
#Which Genre Has the Highest Average Followers?
# Which Genre Has the Highest Average Followers?

# Explode the 'genres' column to have one row per genre per artist
exploded = df.explode('genres')

# Now group by genre and calculate the mean followers
genre_followers = exploded.groupby('genres')['followers'].mean().sort_values(ascending=False).head(10)

print("Top 10 Genres by Average Followers:\n", genre_followers)
# Out:
# Top 10 Genres by Average Followers:
#  genres
# queer country                  4.562300e+06
# country rap                    2.414949e+06
# lgbtq+ hip hop                 1.579826e+06
# albuquerque indie              8.549830e+05
# turkish pop                    5.997552e+05
# musica juiz-forana             5.664110e+05
# k-pop boy group                5.608397e+05
# sertanejo pop                  5.460890e+05
# brazilian progressive metal    5.459700e+05
# trap                           4.904882e+05
# Name: followers, dtype: float64

# %%
#Top 10 Artists by Popularity
top_artists = df.sort_values(by='popularity', ascending=False).head(10)
print("Top 10 Artists by Popularity:\n", top_artists[['name', 'popularity']])
# Out:
# Top 10 Artists by Popularity:
#                         name  popularity
# 6431              Lil Nas X        89.0
# 50506       Los Legendarios        84.0
# 38874     Lofi Fruits Music        84.0
# 8545                 MEDUZA        83.0
# 69996                 Lunay        83.0
# 54721  Tarcísio do Acordeon        81.0
# 59395              Dopamine        80.0
# 59396      Mufasa & Hypeman        80.0
# 41900      Los Dos Carnales        80.0
# 59397             Ali Gatie        79.0

# %%
#Top 10 Artists by Number of Followers
top_artists_followers = df.sort_values(by='followers', ascending=False).head(10)
print("Top 10 Artists by Number of Followers:\n", top_artists_followers[['name', 'followers']])
# Out:
# Top 10 Artists by Number of Followers:
#                 name  followers
# 6431      Lil Nas X  4562300.0
# 69996         Lunay  4287158.0
# 69941      Ferrugem  3966811.0
# 17540       Andmesh  3617747.0
# 56327        MC G15  3492917.0
# 1973    Mano Walter  2639827.0
# 56445        Ultimo  2313612.0
# 49002       Lil Xan  2153178.0
# 53999        MC Lan  2130678.0
# 4997   Paula Mattos  2080285.0

# %%
#Artists are often associated with multiple genres.
#The top 10 most common genres include pop, rap, hip hop, and dance pop.
#Pop and hip hop dominate the industry in terms of both artist count and popularity.
#There is a strong positive correlation (~0.88) between an artist’s followers and their popularity.
#However, having many followers does not always guarantee current popularity — some older or inactive artists retain large follower bases.
#The most followed and most popular artists include many overlapping names, but not all.
#Followers reflect long-term fan interest, while popularity is more dynamic, influenced by current trends and activity.
#A few artists are clear outliers with exceptionally high follower counts or popularity, which may skew aggregate statistics.
